# %% [markdown]
# <a href="https://colab.research.google.com/github/rianviniciusfr/Rian-Vinicius/blob/main/beerconsumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dongeorge/beer-consumption-sao-paulo")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.24k/5.24k [00:00<00:00, 9.73MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dongeorge/beer-consumption-sao-paulo/versions/2

# %%
import pandas as pd
import os

# %%
import pandas as pd
import os

csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
if csv_files:
    csv_file_path = os.path.join(path, csv_files[0])
    df = pd.read_csv(csv_file_path)
    print(f"Loaded '{csv_files[0]}' into a DataFrame.")
    display(df.head())
else:
    print("No CSV files found in the dataset directory.")
# Out:
# Loaded 'Consumo_cerveja.csv' into a DataFrame.
#          Data Temperatura Media (C) Temperatura Minima (C)  \
# 0  2015-01-01                  27,3                   23,9
# 1  2015-01-02                 27,02                   24,5
# 2  2015-01-03                 24,82                   22,4
# 3  2015-01-04                 23,98                   21,5
# 4  2015-01-05                 23,82                     21
#
#   Temperatura Maxima (C) Precipitacao (mm)  Final de Semana  \
# 0                   32,5                 0              0.0
# 1                   33,5                 0              0.0
# 2                   29,9                 0              1.0
# 3                   28,6               1,2              1.0
# 4                   28,3                 0              0.0
#
#    Consumo de cerveja (litros)
# 0                       25.461
# 1                       28.972
# 2                       30.814
# 3                       29.799
# 4                       28.900

# %% [markdown]
# ## 3. Visualizing Relationship with Linear Regression
#
# Let's visualize the relationship between 'Avg_Temp_C' and 'Beer_Consumption_liters' using a scatter plot with a linear regression line.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a linear regression plot
plt.figure(figsize=(10, 6))
sns.regplot(x='Avg_Temp_C', y='Beer_Consumption_liters', data=df_cleaned, scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Linear Regression of Beer Consumption vs. Average Temperature')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Beer Consumption (liters)')
plt.grid(True)
plt.show()
